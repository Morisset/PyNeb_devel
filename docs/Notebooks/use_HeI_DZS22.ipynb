# %%
import pyneb as pn

# %%
HeI_def = pn.RecAtom('He', 1)
print(HeI_def)
# Out:
# Atom He1 from he_i_rec_Pal12-Pal13.hdf5

# %% [markdown]
# ## Look for all the atomic data available for HeI

# %%
pn.atomicData.getAllAvailableFiles('He1')
# Out:
# ['* he_i_rec_Pal12-Pal13.hdf5',
#  'he_i_rec_DZS22.hdf5',
#  'he_i_rec_P91.func',
#  'he_i_rec_Pal12-Pal13.fits',
#  'he_i_rec_Pal12.fits',
#  'he_i_rec_Pal12.hdf5',
#  'he_i_rec_S96_caseA.hdf5',
#  'he_i_rec_S96_caseB.hdf5']

# %% [markdown]
# ## Select the Del Zanna & Storey data

# %%
pn.atomicData.setDataFile('he_i_rec_DZS22.hdf5')

# %% [markdown]
# ## Instantiate a RecAtom object

# %%
HeI = pn.RecAtom('He', 1)

# %% [markdown]
# ## Check the source of the atomic data

# %%
HeI.printSources()
# Out:
# Del Zanna & Storey, 2022, MNRAS, 513, 1198

# %% [markdown]
# ## Print out all the available transitions, identified by wavelength in string type

# %%
HeI.labels
# Out:
# ('20586.90',
#  '5017.08',
#  '3965.85',
#  '3614.67',
#  '3448.58',
#  '3355.52',
#  '3297.72',
#  '3259.21',
#  '3232.20',
#  '3212.50',
#  '3197.67',
#  '3186.22',
#  '3177.19',
#  '3169.94',
#  '3164.03',
#  '3159.15',
#  '3155.07',
#  '3151.62',
#  '3148.69',
#  '3146.17',
#  '3143.98',
#  '3142.08',
#  '3140.41',
#  '3138.94',
#  '74375.12',
#  '15087.77',
#  '11016.09',
#  '9606.07',
#  '8917.22',
#  '8520.38',
#  '8267.97',
#  '8096.34',
#  '7973.82',
#  '7883.07',
#  '7813.84',
#  '7759.76',
#  '7716.66',
#  '7681.74',
#  '7653.03',
#  '7629.13',
#  '7609.02',
#  '7591.94',
#  '7577.29',
#  '7564.64',
#  '7553.64',
#  '7544.01',
#  '7535.54',
#  '1.810e+05',
#  '33308.51',
#  '23069.74',
#  '19459.56',
#  '17664.18',
#  '16612.77',
#  '15934.06',
#  '15466.38',
#  '15128.55',
#  '14875.62',
#  '14680.83',
#  '14527.33',
#  '14404.05',
#  '14303.44',
#  '14220.20',
#  '14150.49',
#  '14091.51',
#  '14041.14',
#  '13997.77',
#  '13960.14',
#  '13927.29',
#  '13898.42',
#  '3.580e+05',
#  '62057.98',
#  '41398.00',
#  '34038.06',
#  '30338.14',
#  '28148.58',
#  '26721.16',
#  '25728.55',
#  '25005.49',
#  '24459.93',
#  '24036.78',
#  '23701.15',
#  '23429.97',
#  '23207.42',
#  '23022.34',
#  '22866.62',
#  '22734.28',
#  '22620.80',
#  '22522.71',
#  '22437.31',
#  '22362.49',
#  '7283.36',
#  '6680.00',
#  '5049.15',
#  '4923.31',
#  '4438.80',
#  '4389.16',
#  '4170.15',
#  '4144.93',
#  '4025.12',
#  '4010.39',
#  '3937.06',
#  '3927.66',
#  '3879.28',
#  '3872.88',
#  '3839.19',
#  '3834.64',
#  '3810.18',
#  '3806.82',
#  '3788.49',
#  '3785.94',
#  '3771.83',
#  '3769.84',
#  '3758.75',
#  '3757.17',
#  '3748.28',
#  '3747.00',
#  '3739.77',
#  '3738.73',
#  '3732.77',
#  '3731.90',
#  '3726.92',
#  '3726.19',
#  '3721.99',
#  '3721.38',
#  '3717.80',
#  '3717.28',
#  '3714.21',
#  '3713.76',
#  '3711.10',
#  '3710.71',
#  '3708.40',
#  '3708.05',
#  '3706.03',
#  '3705.73',
#  '3703.95',
#  '3703.68',
#  '21137.80',
#  '19094.57',
#  '13415.35',
#  '12971.98',
#  '11229.01',
#  '11048.01',
#  '10235.91',
#  '10141.20',
#  '9685.04',
#  '9628.34',
#  '9342.71',
#  '9305.72',
#  '9113.53',
#  '9087.91',
#  '8951.76',
#  '8933.22',
#  '8832.94',
#  '8819.06',
#  '8742.89',
#  '8732.21',
#  '8672.92',
#  '8664.51',
#  '8617.40',
#  '8610.66',
#  '8572.57',
#  '8567.08',
#  '8535.83',
#  '8531.29',
#  '8505.33',
#  '8501.54',
#  '8479.72',
#  '8476.52',
#  '8458.00',
#  '8455.27',
#  '8439.42',
#  '8437.07',
#  '8423.39',
#  '8421.36',
#  '8409.48',
#  '8407.70',
#  '8397.31',
#  '8395.75',
#  '8386.61',
#  '8385.24',
#  '46065.96',
#  '41227.29',
#  '27607.86',
#  '26538.87',
#  '22290.66',
#  '21846.38',
#  '19833.98',
#  '19597.61',
#  '18449.54',
#  '18305.84',
#  '17576.69',
#  '17481.67',
#  '16984.73',
#  '16918.13',
#  '16562.01',
#  '16513.27',
#  '16248.23',
#  '16211.38',
#  '16008.20',
#  '15979.59',
#  '15820.07',
#  '15797.37',
#  '15669.64',
#  '15651.30',
#  '15547.32',
#  '15532.28',
#  '15446.43',
#  '15433.93',
#  '15362.17',
#  '15351.66',
#  '15291.04',
#  '15282.12',
#  '15230.41',
#  '15222.77',
#  '15178.30',
#  '15171.70',
#  '15133.17',
#  '15127.43',
#  '15093.81',
#  '15088.79',
#  '15059.28',
#  '15054.86',
#  '85294.65',
#  '75854.80',
#  '49105.47',
#  '46999.86',
#  '38578.73',
#  '37694.43',
#  '33665.04',
#  '33189.66',
#  '30867.98',
#  '30576.11',
#  '29087.60',
#  '28892.80',
#  '27869.40',
#  '27731.68',
#  '26992.27',
#  '26890.71',
#  '26336.26',
#  '26258.89',
#  '25830.89',
#  '25770.42',
#  '25432.24',
#  '25383.97',
#  '25111.59',
#  '25072.37',
#  '24849.42',
#  '24817.09',
#  '24632.07',
#  '24605.07',
#  '24449.71',
#  '24426.91',
#  '24295.07',
#  '24275.64',
#  '24162.75',
#  '24146.03',
#  '24048.57',
#  '24034.09',
#  '23949.33',
#  '23936.70',
#  '23862.51',
#  '23851.41',
#  '9.580e+05',
#  '18702.32',
#  '18560.64',
#  '12794.00',
#  '12759.18',
#  '10920.05',
#  '10905.19',
#  '10033.90',
#  '10025.95',
#  '9531.87',
#  '9527.05',
#  '9215.76',
#  '9212.58',
#  '9002.21',
#  '8999.99',
#  '8850.47',
#  '8848.85',
#  '8738.44',
#  '8737.23',
#  '8653.20',
#  '8652.26',
#  '8586.74',
#  '8586.00',
#  '8533.86',
#  '8533.27',
#  '8491.07',
#  '8490.59',
#  '8455.93',
#  '8455.53',
#  '8426.70',
#  '8426.37',
#  '8402.12',
#  '8401.84',
#  '8381.25',
#  '8381.01',
#  '8363.38',
#  '8363.17',
#  '8347.94',
#  '8347.76',
#  '8334.53',
#  '8334.37',
#  '8322.79',
#  '8322.65',
#  '8312.45',
#  '8312.33',
#  '1.840e+07',
#  '2.160e+06',
#  '40409.34',
#  '40064.00',
#  '26205.62',
#  '26120.21',
#  '21622.91',
#  '21586.00',
#  '19418.88',
#  '19398.85',
#  '18150.49',
#  '18138.16',
#  '17340.34',
#  '17332.12',
#  '16785.99',
#  '16780.19',
#  '16387.53',
#  '16383.27',
#  '16090.29',
#  '16087.05',
#  '15862.00',
#  '15859.48',
#  '15682.50',
#  '15680.50',
#  '15538.59',
#  '15536.97',
#  '15421.31',
#  '15419.97',
#  '15324.38',
#  '15323.27',
#  '15243.29',
#  '15242.36',
#  '15174.74',
#  '15173.95',
#  '15116.24',
#  '15115.56',
#  '15065.89',
#  '15065.31',
#  '15022.25',
#  '15021.74',
#  '14984.15',
#  '14983.70',
#  '14950.69',
#  '14950.30',
#  '3.520e+07',
#  '4.140e+06',
#  '74396.91',
#  '73712.69',
#  '46449.17',
#  '46279.21',
#  '37344.20',
#  '37270.18',
#  '32920.10',
#  '32879.56',
#  '30348.43',
#  '30323.25',
#  '28690.15',
#  '28673.22',
#  '27545.42',
#  '27533.38',
#  '26715.86',
#  '26706.94',
#  '26092.36',
#  '26085.54',
#  '25610.17',
#  '25604.83',
#  '25228.60',
#  '25224.32',
#  '24920.87',
#  '24917.39',
#  '24668.72',
#  '24665.85',
#  '24459.28',
#  '24456.88',
#  '24283.25',
#  '24281.22',
#  '24133.79',
#  '24132.06',
#  '24005.72',
#  '24004.23',
#  '23895.09',
#  '23893.80',
#  '23798.84',
#  '23797.71',
#  '23714.55',
#  '23713.56',
#  '40545.05',
#  '40490.35',
#  '26254.48',
#  '26241.00',
#  '21653.31',
#  '21647.49',
#  '19442.10',
#  '19438.94',
#  '18170.09',
#  '18168.14',
#  '17357.82',
#  '17356.52',
#  '16802.11',
#  '16801.19',
#  '16402.72',
#  '16402.05',
#  '16104.82',
#  '16104.31',
#  '15876.04',
#  '15875.64',
#  '15696.16',
#  '15695.85',
#  '15551.96',
#  '15551.70',
#  '15434.44',
#  '15434.23',
#  '15337.31',
#  '15337.14',
#  '15256.07',
#  '15255.92',
#  '15187.39',
#  '15187.26',
#  '15128.77',
#  '15128.67',
#  '15078.33',
#  '15078.24',
#  '15034.61',
#  '15034.52',
#  '14996.44',
#  '14996.37',
#  '14962.92',
#  '14962.85',
#  '2.040e+08',
#  '74646.94',
#  '74538.07',
#  '46533.33',
#  '46506.43',
#  '37393.76',
#  '37382.05',
#  '32956.34',
#  '32949.93',
#  '30377.98',
#  '30373.99',
#  '28715.82',
#  '28713.14',
#  '27568.60',
#  '27566.69',
#  '26737.34',
#  '26735.93',
#  '26112.62',
#  '26111.54',
#  '25629.53',
#  '25628.68',
#  '25247.26',
#  '25246.58',
#  '24938.99',
#  '24938.44',
#  '24686.40',
#  '24685.95',
#  '24476.61',
#  '24476.23',
#  '24300.29',
#  '24299.97',
#  '24150.58',
#  '24150.30',
#  '24022.30',
#  '24022.06',
#  '23911.50',
#  '23911.29',
#  '23815.09',
#  '23814.92',
#  '23730.67',
#  '23730.51',
#  '74581.79',
#  '74561.55',
#  '46521.17',
#  '46516.08',
#  '37390.72',
#  '37388.49',
#  '32956.25',
#  '32955.02',
#  '30379.15',
#  '30378.37',
#  '28717.61',
#  '28717.09',
#  '27570.73',
#  '27570.35',
#  '26739.66',
#  '26739.39',
#  '26115.06',
#  '26114.85',
#  '25632.04',
#  '25631.87',
#  '25249.82',
#  '25249.69',
#  '24941.58',
#  '24941.47',
#  '24689.01',
#  '24688.92',
#  '24479.23',
#  '24479.15',
#  '24302.92',
#  '24302.85',
#  '24153.21',
#  '24153.16',
#  '24024.94',
#  '24024.89',
#  '23914.13',
#  '23914.09',
#  '23817.73',
#  '23817.69',
#  '23733.31',
#  '23733.27',
#  '10833.14',
#  '3889.74',
#  '3188.67',
#  '2945.96',
#  '2829.91',
#  '2764.62',
#  '2724.00',
#  '2696.92',
#  '2677.92',
#  '2664.07',
#  '2653.65',
#  '2645.60',
#  '2639.26',
#  '2634.17',
#  '2630.03',
#  '2626.60',
#  '2623.74',
#  '2621.33',
#  '2619.27',
#  '2617.51',
#  '2615.98',
#  '2614.65',
#  '2613.48',
#  '2612.45',
#  '42958.83',
#  '12530.91',
#  '9466.18',
#  '8364.03',
#  '7818.29',
#  '7501.92',
#  '7300.05',
#  '7162.53',
#  '7064.27',
#  '6991.45',
#  '6935.89',
#  '6892.48',
#  '6857.88',
#  '6829.86',
#  '6806.82',
#  '6787.65',
#  '6771.52',
#  '6757.81',
#  '6746.07',
#  '6735.93',
#  '6727.11',
#  '6719.39',
#  '6712.60',
#  '1.090e+05',
#  '28550.20',
#  '20430.54',
#  '17454.43',
#  '15952.52',
#  '15066.55',
#  '14492.29',
#  '14095.60',
#  '13808.61',
#  '13593.52',
#  '13427.77',
#  '13297.10',
#  '13192.14',
#  '13106.46',
#  '13035.56',
#  '12976.19',
#  '12925.96',
#  '12883.06',
#  '12846.13',
#  '12814.10',
#  '12786.12',
#  '12761.55',
#  '2.200e+05',
#  '54178.33',
#  '37308.89',
#  '31058.58',
#  '27868.03',
#  '25964.97',
#  '24718.61',
#  '23849.38',
#  '23214.97',
#  '22735.68',
#  '22363.58',
#  '22068.25',
#  '21829.53',
#  '21633.56',
#  '21470.55',
#  '21333.37',
#  '21216.78',
#  '21116.80',
#  '21030.37',
#  '20955.13',
#  '20889.21',
#  '7067.20',
#  '5877.29',
#  '4714.49',
#  '4472.76',
#  '4122.00',
#  '4027.35',
#  '3868.59',
#  '3820.71',
#  '3733.94',
#  '3706.07',
#  '3653.04',
#  '3635.29',
#  '3600.35',
#  '3588.30',
#  '3564.00',
#  '3555.44',
#  '3537.83',
#  '3531.51',
#  '3518.32',
#  '3513.53',
#  '3503.39',
#  '3499.66',
#  '3491.69',
#  '3488.73',
#  '3482.35',
#  '3479.97',
#  '3474.78',
#  '3472.82',
#  '3468.55',
#  '3466.93',
#  '3463.36',
#  '3462.00',
#  '3459.00',
#  '3457.85',
#  '3455.29',
#  '3454.31',
#  '3452.11',
#  '3451.26',
#  '3449.37',
#  '3448.63',
#  '3446.98',
#  '3446.34',
#  '3444.89',
#  '3444.33',
#  '3443.06',
#  '3442.56',
#  '1.860e+05',
#  '21125.97',
#  '17007.14',
#  '12849.52',
#  '11972.39',
#  '10670.63',
#  '10314.09',
#  '9705.31',
#  '9519.21',
#  '9177.04',
#  '9065.80',
#  '8851.61',
#  '8779.15',
#  '8635.11',
#  '8585.00',
#  '8483.02',
#  '8446.80',
#  '8371.74',
#  '8344.63',
#  '8287.67',
#  '8266.83',
#  '8222.50',
#  '8206.12',
#  '8170.92',
#  '8157.78',
#  '8129.35',
#  '8118.65',
#  '8095.33',
#  '8086.51',
#  '8067.14',
#  '8059.76',
#  '8043.49',
#  '8037.27',
#  '8023.47',
#  '8018.16',
#  '8006.35',
#  '8001.79',
#  '7991.61',
#  '7987.66',
#  '7978.81',
#  '7975.37',
#  '7967.63',
#  '7964.62',
#  '7957.81',
#  '7955.15',
#  '4.400e+05',
#  '46949.81',
#  '37035.72',
#  '26888.50',
#  '24734.01',
#  '21499.92',
#  '20607.44',
#  '19068.31',
#  '18594.25',
#  '17715.01',
#  '17427.16',
#  '16868.59',
#  '16678.43',
#  '16297.80',
#  '16164.62',
#  '15891.94',
#  '15794.56',
#  '15591.70',
#  '15518.11',
#  '15362.66',
#  '15305.55',
#  '15183.56',
#  '15138.27',
#  '15040.63',
#  '15004.07',
#  '14924.61',
#  '14894.64',
#  '14829.06',
#  '14804.16',
#  '14749.36',
#  '14728.45',
#  '14682.17',
#  '14664.41',
#  '14624.96',
#  '14609.75',
#  '14575.83',
#  '14562.70',
#  '14533.31',
#  '14521.91',
#  '14496.27',
#  '14486.29',
#  '14463.79',
#  '14455.01',
#  '8.590e+05',
#  '88074.38',
#  '68523.33',
#  '48367.10',
#  '44073.10',
#  '37584.86',
#  '35786.54',
#  '32666.16',
#  '31700.63',
#  '29899.68',
#  '29307.38',
#  '28152.06',
#  '27757.02',
#  '26962.61',
#  '26683.50',
#  '26109.60',
#  '25903.87',
#  '25473.61',
#  '25316.97',
#  '24984.93',
#  '24862.54',
#  '24600.26',
#  '24502.60',
#  '24291.41',
#  '24212.10',
#  '24039.28',
#  '23973.92',
#  '23830.55',
#  '23775.99',
#  '23655.62',
#  '23609.56',
#  '23507.46',
#  '23468.20',
#  '23380.79',
#  '23347.04',
#  '23271.59',
#  '23242.36',
#  '23176.76',
#  '23151.25',
#  '23093.85',
#  '23071.46',
#  '19548.43',
#  '18690.46',
#  '12988.43',
#  '12788.44',
#  '10999.66',
#  '10915.99',
#  '10074.79',
#  '10030.47',
#  '9555.52',
#  '9528.78',
#  '9230.39',
#  '9212.86',
#  '9011.63',
#  '8999.45',
#  '8856.63',
#  '8847.80',
#  '8742.47',
#  '8735.84',
#  '8655.76',
#  '8650.65',
#  '8588.26',
#  '8584.23',
#  '8534.61',
#  '8531.38',
#  '8491.25',
#  '8488.61',
#  '8455.67',
#  '8453.49',
#  '8426.10',
#  '8424.28',
#  '8401.26',
#  '8399.72',
#  '8380.17',
#  '8378.86',
#  '8362.12',
#  '8360.99',
#  '8346.55',
#  '8345.57',
#  '8333.01',
#  '8332.16',
#  '8321.17',
#  '8320.42',
#  '8310.76',
#  '8310.10',
#  '1.350e+07',
#  '42440.67',
#  '40377.35',
#  '26679.03',
#  '26192.13',
#  '21820.57',
#  '21613.71',
#  '19522.75',
#  '19411.47',
#  '18212.12',
#  '18144.01',
#  '17379.67',
#  '17334.43',
#  '16812.26',
#  '16780.45',
#  '16405.58',
#  '16382.25',
#  '16102.87',
#  '16085.20',
#  '15870.80',
#  '15857.05',
#  '15688.58',
#  '15677.66',
#  '15542.67',
#  '15533.84',
#  '15423.87',
#  '15416.62',
#  '15325.78',
#  '15319.75',
#  '15243.79',
#  '15238.72',
#  '15174.51',
#  '15170.21',
#  '15115.43',
#  '15111.74',
#  '15064.61',
#  '15061.42',
#  '15020.58',
#  '15017.80',
#  '14982.15',
#  '14979.73',
#  '14948.43',
#  '14946.29',
#  '2.520e+07',
#  '78394.84',
#  '74334.39',
#  '47389.67',
#  '46424.75',
#  '37742.11',
#  '37328.39',
#  '33132.56',
#  '32907.81',
#  '30476.84',
#  '30337.98',
#  '28773.89',
#  '28680.85',
#  '27602.81',
#  '27536.83',
#  '26756.54',
#  '26707.77',
#  '26121.86',
#  '26084.64',
#  '25631.86',
#  '25602.72',
#  '25244.66',
#  '25221.37',
#  '24932.76',
#  '24913.82',
#  '24677.44',
#  '24661.81',
#  '24465.54',
#  '24452.48',
#  '24287.59',
#  '24276.56',
#  '24136.58',
#  '24127.17',
#  '24007.27',
#  '23999.17',
#  '23895.63',
#  '23888.61',
#  '23798.54',
#  '23792.41',
#  '23713.55',
#  '23708.16',
#  '40563.46',
#  '40490.15',
#  '26259.18',
#  '26240.91',
#  '21655.37',
#  '21647.42',
#  '19443.22',
#  '19438.88',
#  '18170.76',
#  '18168.08',
#  '17358.26',
#  '17356.47',
#  '16802.41',
#  '16801.14',
#  '16402.94',
#  '16402.00',
#  '16104.97',
#  '16104.27',
#  '15876.15',
#  '15875.60',
#  '15696.25',
#  '15695.81',
#  '15552.02',
#  '15551.66',
#  '15434.48',
#  '15434.19',
#  '15337.34',
#  '15337.10',
#  '15256.09',
#  '15255.89',
#  '15187.40',
#  '15187.22',
#  '15128.78',
#  '15128.63',
#  '15078.20',
#  '15034.60',
#  '15034.49',
#  '14996.43',
#  '14996.33',
#  '14962.90',
#  '14962.82',
#  '2.020e+08',
#  '74685.32',
#  '74537.69',
#  '46542.97',
#  '46506.26',
#  '37397.98',
#  '37381.94',
#  '32958.64',
#  '32949.83',
#  '30379.40',
#  '30373.91',
#  '28716.76',
#  '28713.06',
#  '27569.26',
#  '27566.63',
#  '26737.82',
#  '26735.86',
#  '26112.97',
#  '26111.48',
#  '25629.79',
#  '25628.62',
#  '25247.46',
#  '25246.52',
#  '24939.15',
#  '24938.38',
#  '24686.52',
#  '24685.89',
#  '24476.70',
#  '24476.17',
#  '24300.36',
#  '24299.91',
#  '24150.63',
#  '24150.25',
#  '24022.34',
#  '24022.01',
#  '23911.52',
#  '23911.24',
#  '23815.11',
#  '23814.86',
#  '23730.68',
#  '23730.46',
#  '74581.87',
#  '74561.40',
#  '46521.15',
#  '46516.01',
#  '37390.70',
#  '37388.43',
#  '32956.23',
#  '32954.98',
#  '30379.12',
#  ...)

# %% [markdown]
# ## Use the dedicated tool to identify the desired label

# %%
pn.atomicData.getDZN22Level_from_wl?
# Out:
# Signature:
# pn.atomicData.getDZN22Level_from_wl(
#     wl,
#     wl_in_air=True,
#     tol_wl=0.001,
#     getDetailed=False,
# )
# Docstring:
# Return the level for the del Zanna & Storey 22 HeI lines from the wavelength
# wl: wavelength in Angstrom
# wl_in_air [True]: if True, wl is in air
# tol_wl [0.01]: tolerance in wavelength
# getDetailed [False]: if True, return the detailed level information, else only
#     the label (wl in vacuum)
# File:      ~/Google Drive/Pro/PyNeb_devel/pyneb/utils/manage_atomic_data.py
# Type:      method

# %% [markdown]
# ### Look for the correct label for a given wavelength (in air, $\AA$). The returned label corresponds to the wavelength in vacuum.

# %%
pn.atomicData.getDZN22Level_from_wl(4471)
# Out:
# '4472.76'

# %% [markdown]
# ### Using the wavelength in vacuum

# %%
pn.atomicData.getDZN22Level_from_wl(4471, wl_in_air=False)
# Out:
# '4472.76'

# %% [markdown]
# ### get more details about the returned transition
# The method returns Spin, n and L for lower and upper levels, and wavelengths in vacuum and air

# %%
pn.atomicData.getDZN22Level_from_wl(4471, getDetailed=True)
# Out:
# array([(3, 2, 'P', 4, 'D', '4472.76', '4471.50')],
#       dtype=[('S', '<i4'), ('n_low', '<i4'), ('L_low', '<U2'), ('n_up', '<i4'), ('L_up', '<U2'), ('wl', '<U10'), ('wl_air', '<U10')])

# %% [markdown]
# ### For some wavelength, more than one label can be returned

# %%
pn.atomicData.getDZN22Level_from_wl(8359)
# Out:
# array(['8363.38', '8363.17', '8364.03', '8362.12', '8360.99'],
#       dtype='<U10')

# %%
pn.atomicData.getDZN22Level_from_wl(8359, getDetailed=True)
# Out:
# array([(1, 3, 'D', 21, 'F', '8363.38', '8361.08'),
#        (1, 3, 'D', 21, 'P', '8363.17', '8360.87'),
#        (3, 3, 'S',  6, 'P', '8364.03', '8361.73'),
#        (3, 3, 'D', 21, 'P', '8362.12', '8359.83'),
#        (3, 3, 'D', 21, 'F', '8360.99', '8358.70')],
#       dtype=[('S', '<i4'), ('n_low', '<i4'), ('L_low', '<U2'), ('n_up', '<i4'), ('L_up', '<U2'), ('wl', '<U10'), ('wl_air', '<U10')])

# %% [markdown]
# ### The returned set of labels depends on the tol_wl = delta_wl / wl used. The default is 0.001

# %%
pn.atomicData.getDZN22Level_from_wl(4471, getDetailed=True, tol_wl=0.01)
# Out:
# array([(1, 2, 'P', 5, 'S', '4438.80', '4437.55'),
#        (3, 2, 'P', 4, 'D', '4472.76', '4471.50')],
#       dtype=[('S', '<i4'), ('n_low', '<i4'), ('L_low', '<U2'), ('n_up', '<i4'), ('L_up', '<U2'), ('wl', '<U10'), ('wl_air', '<U10')])

# %% [markdown]
# ## Compare values from default atomic data and Del Zanna & Storey 2022

# %% [markdown]
# The floating point value of the wavelength is used to obtain the corresponding label

# %%
print(HeI_def.getEmissivity(1.1e4, 1e2, wave = 4471.), 
      HeI.getEmissivity(1.1e4, 1e2, label = pn.atomicData.getDZN22Level_from_wl(4471.)))
# Out:
# 5.571472612332774e-26 5.553414638651924e-26
